# %% [markdown]
# ## Community Analysis

# %% [markdown]
# This notebook will summarize important attributes of a community from given building inventory and housing unit allocation information. This helps in understanding the data of the community avaiable on IN-CORE

# %%
## Importing all the modules from incore

import os
import pandas as pd
import geopandas as gpd
import contextily as ctx
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]=12,10
from texttable import Texttable
from pyincore import IncoreClient, Dataset, FragilityService, MappingSet, DataService
from pyincore.analyses.buildingdamage import BuildingDamage
from pyincore.analyses.cumulativebuildingdamage import CumulativeBuildingDamage
from pyincore.analyses.populationdislocation import PopulationDislocation, PopulationDislocationUtil
from pyincore.analyses.housingunitallocation import HousingUnitAllocation

from pyincore_viz.geoutil import GeoUtil as viz
import warnings
warnings.filterwarnings('ignore')

# %%
client = IncoreClient()
data_service = DataService(client)
# Out:
# Connection successful to IN-CORE services. pyIncore version detected: 0.9.0

# %% [markdown]
# ### INPUT DATA

# %% [markdown]
# The building inventory information should be given in .csv format
# The housing unit allocatoin information given in .csv format

# %%
#Input data
bInv = pd.read_csv("Seaside_Building_Inventory_xy.csv") #Building Inventory Data
hua = pd.read_csv("IN-CORE_1cv1_housingunitallocation_1238.csv") #Housing Unit Allocation Data (The ouput file oh housing unit analysis)

# %% [markdown]
# #### Option to remove outlier

# %%
outlier = int(input("1 for no outlier, 0 for outlier"))
# Out:
# 1 for no outlier, 0 for outlier1

# %%
if outlier==1:
    #Run this cell only if you want to remove outliers
    old_len = len(bInv)
    bInv = bInv[(bInv.appr_bldg>10000) & (bInv.appr_bldg<1e6)]
    bInv = bInv[(bInv.year_built>1900) & (bInv.year_built<2011)]
    print("Rows dropped: {}".format(old_len - len(bInv)))
# Out:
# Rows dropped: 378

# %% [markdown]
# ###### Converting the data frame to gdf

# %%
# Use shapely.wkt loads to convert WKT to GeoSeries
from shapely.geometry import Point
# Geodata frame requires geometry and CRS to be set
hua_gdf = gpd.GeoDataFrame(
    hua,
    crs={'init': 'epsg:4326'},
    geometry=[Point(xy) for xy in zip(hua['x'], hua['y'])])
hua_gdf[['guid','x','y','numprec','geometry']].head(6)
# Out:
#                                    guid           x          y  numprec  \
# 0  e38d8575-7880-4a8c-b6d7-225ab1cf9264 -123.896065  46.012722      2.0
# 1  af5771b4-4f42-4166-b772-78a3706fa8ac -123.903427  46.017498      1.0
# 2  37532fb5-5107-478b-ab2c-158eb001c68b -123.903427  46.017498      4.0
# 3  66d39314-1c68-4634-a82c-8fcb37f529ff -123.900246  46.013523      3.0
# 4  e519ec32-c5eb-422a-be3d-7ff4bb33f1e2 -123.898918  46.012257      2.0
# 5  0edcff97-8fa1-4558-b80e-610abe7b9f17 -123.898552  46.012253      7.0
#
#                       geometry
# 0  POINT (-123.89606 46.01272)
# 1  POINT (-123.90343 46.01750)
# 2  POINT (-123.90343 46.01750)
# 3  POINT (-123.90025 46.01352)
# 4  POINT (-123.89892 46.01226)
# 5  POINT (-123.89855 46.01225)

# %%
# Use shapely.wkt loads to convert WKT to GeoSeries
from shapely.geometry import Point
# Geodata frame requires geometry and CRS to be set
bldg_inv_gdf = gpd.GeoDataFrame(
    bInv,
    crs={'init': 'epsg:4326'},
    geometry=[Point(xy) for xy in zip(bInv['x'], bInv['y'])])
bldg_inv_gdf[['guid','x','y','year_built','geometry']].head(6)
# Out:
#                                     guid           x          y  year_built  \
# 1   65d6e370-c05b-4b2f-bd17-d914d1d056c7 -123.905846  45.997948        1992
# 5   9020fc6c-4b0e-4e5b-b8be-fa58141b57b5 -123.905846  45.997948        2007
# 10  0b4073d3-7d7e-439d-b9ef-1373291f37cc -123.905846  45.997948        1992
# 11  bef20397-d546-475e-8dfd-b58a422019d8 -123.903778  46.003887        2006
# 12  f5e2c264-da77-4971-99d8-0c3d7562b986 -123.915581  45.996147        1988
# 13  d8ffb229-86e0-4907-97a5-84eb9ac248e6         NaN        NaN        1959
#
#                        geometry
# 1   POINT (-123.90585 45.99795)
# 5   POINT (-123.90585 45.99795)
# 10  POINT (-123.90585 45.99795)
# 11  POINT (-123.90378 46.00389)
# 12  POINT (-123.91558 45.99615)
# 13              POINT (nan nan)

# %%
bInv.columns
#important ones are appr_bldg, struct_typ, year_built
#should have unique guid
# Out:
# Index(['Unnamed: 0', 'parid', 'parid_card', 'bldg_id', 'struct_typ',
#        'str_prob', 'year_built', 'no_stories', 'a_stories', 'b_stories',
#        'bsmt_type', 'sq_foot', 'gsq_foot', 'occ_type', 'occ_detail',
#        'major_occ', 'broad_occ', 'appr_bldg', 'repl_cst', 'str_cst',
#        'nstra_cst', 'nstrd_cst', 'dgn_lvl', 'cont_val', 'efacility',
#        'dwell_unit', 'str_typ2', 'occ_typ2', 'tract_id', 'guid', 'FID_NEW',
#        'origin', 'stat_class', 'rmv_improv', 'rmv_land', 'elev', 'period',
#        'strctid', 'x', 'y', 'value_matc', 'geometry'],
#       dtype='object')

# %%
hua.columns
#important ones are race, hispan, gqtype
# Out:
# Index(['Unnamed: 0', 'addrptid', 'parid', 'parid_card', 'bldg_id',
#        'struct_typ', 'str_prob', 'year_built', 'no_stories', 'a_stories',
#        'b_stories', 'bsmt_type', 'sq_foot', 'gsq_foot', 'occ_type',
#        'occ_detail', 'major_occ', 'broad_occ', 'appr_bldg', 'repl_cst',
#        'str_cst', 'nstra_cst', 'nstrd_cst', 'dgn_lvl', 'cont_val', 'efacility',
#        'dwell_unit', 'str_typ2', 'occ_typ2', 'tract_id', 'guid', 'FID_NEW',
#        'origin', 'stat_class', 'rmv_improv', 'rmv_land', 'elev', 'period',
#        'strctid', 'value_matc', 'blockid', 'huestimate', 'residential', 'x',
#        'y', 'randomap', 'randommergeorder', 'blockidstr', 'huid', 'livetype',
#        'numprec', 'ownershp', 'race', 'hispan', 'vacancy', 'gqtype', 'bgid',
#        'randomhu', 'aphumerge', 'geometry', 'Race Ethnicity', 'Tenure Status'],
#       dtype='object')

# %% [markdown]
# ### Buildings Count per blocklevel / parcel / groupid etc

# %%
Building_Data = Texttable()
header_Ages = [ "Items","Values"]
Building_Data.add_row(header_Ages)
Building_Data.add_row(["Total Number of Blocks",len(hua['blockid'].unique())])
Building_Data.add_row(["Total Number of Buildings",len(hua["guid"].unique())])
Building_Data.add_row(["Total Number of Achetype",len(bInv["str_typ2"].unique())])
Building_Data.add_row(["Total Number of Residential Building",np.sum(hua.residential)])
Building_Data.add_row(["Total Number of Non-residential Building",np.sum(hua.residential != 1)])
print(Building_Data.draw())
# Out:
# +------------------------------------------+--------+
# | Items                                    | Values |
# +------------------------------------------+--------+
# | Total Number of Blocks                   | 231    |
# +------------------------------------------+--------+
# | Total Number of Buildings                | 4679   |
# +------------------------------------------+--------+
# | Total Number of Achetype                 | 3      |
# +------------------------------------------+--------+
# | Total Number of Residential Building     | 5988   |
# +------------------------------------------+--------+
# | Total Number of Non-residential Building | 992    |
# +------------------------------------------+--------+

# %% [markdown]
# ### Archtype

# %%
#present this table nicely - pivot table - Nathanael's notebook
pd.DataFrame(bInv.struct_typ.value_counts())
# Out:
#     struct_typ
# W1        2279
# RC        1341
# W2         681

# %%
strct_typ_map = viz.plot_gdf_map(bldg_inv_gdf,column='struct_typ')
plt.title("Structure Type Distribution")
# Out:
# Text(0.5, 1.0, 'Structure Type Distribution')

# %% [markdown]
# ### Appraisal Value

# %%
if outlier==1:
    bInv.appr_bldg.hist(bins=30, alpha = 0.5, grid=False)
    plt.title("Appraisal Value Distribution")
else:
    bInv.appr_bldg.hist(bins=300, alpha = 0.5, grid=False)
    plt.xlim(0, 1e6)
    plt.title("Appraisal Value Distribution")

# %%
#Grouping population
bldg_inv_gdf["new_appr"] = bldg_inv_gdf.appr_bldg.copy()
bldg_inv_gdf.new_appr[bldg_inv_gdf.appr_bldg <10000] = "Below $10,000"
bldg_inv_gdf.new_appr[(bldg_inv_gdf.appr_bldg > 10000) | (bldg_inv_gdf.appr_bldg < 100000)] = "$10,000 - $100,000"
bldg_inv_gdf.new_appr[(bldg_inv_gdf.appr_bldg > 100000) & (bldg_inv_gdf.appr_bldg < 300000)] = "$100,000 - $300,000"
bldg_inv_gdf.new_appr[(bldg_inv_gdf.appr_bldg > 300000) & (bldg_inv_gdf.appr_bldg < 500000)] = "$300,000 - $500,000"
bldg_inv_gdf.new_appr[(bldg_inv_gdf.appr_bldg > 500000) & (bldg_inv_gdf.appr_bldg < 1000000)] = "$500,000 - $1,000,000"
bldg_inv_gdf.new_appr[(bldg_inv_gdf.appr_bldg > 1000000) & (bldg_inv_gdf.appr_bldg < 5000000)] = "$1,000,000 - $5,000,000"
bldg_inv_gdf.new_appr[bldg_inv_gdf.appr_bldg> 5000000] = "Above $5,00,000"

# %%
appr_bldg_map = viz.plot_gdf_map(bldg_inv_gdf,column='new_appr')
plt.title("Appraisal Value")
# Out:
# Text(0.5, 1.0, 'Appraisal Value')

# %% [markdown]
# ### Building Age

# %%
if outlier==1:
    bInv.year_built.hist(bins=25, alpha = 0.5, grid=False)
    plt.title("Year Built Distribution")
else:
    bInv.year_built.hist(bins=300, alpha = 0.5, grid=False)
    plt.xlim(0, 1e6)
    plt.title("Year Built Distribution")

# %%
Retrofit = bInv["dgn_lvl"].value_counts()
print("Total Number of Buildings in the community for each Retrofit Level: \n", Retrofit)
# Out:
# Total Number of Buildings in the community for each Retrofit Level:
#  Pre - Code         2283
# Moderate - Code     818
# Low - Code          696
# High - Code         504
# Name: dgn_lvl, dtype: int64

# %%
year_built_map = viz.plot_gdf_map(bldg_inv_gdf,column='dgn_lvl')
plt.title("Distribution of buildings in each design level")
# Out:
# Text(0.5, 1.0, 'Distribution of buildings in each design level')

# %% [markdown]
# ### Pivot Table for Year Built

# %%
Year_Built = Texttable()
header_Ages = [ "Items","Values"]
Year_Built.add_row(header_Ages)
Year_Built.add_row(["Mean",bInv["year_built"].mean()])
Year_Built.add_row(["Standard Deviation",bInv["year_built"].std()])
Year_Built.add_row(["Median",bInv["year_built"].median()])
Year_Built.add_row(["Max",bInv["year_built"].max()])
Year_Built.add_row(["Min",bInv["year_built"].min()])
print(Year_Built.draw())
# Out:
# +--------------------+----------+
# | Items              | Values   |
# +--------------------+----------+
# | Mean               | 1966.896 |
# +--------------------+----------+
# | Standard Deviation | 31.979   |
# +--------------------+----------+
# | Median             | 1973     |
# +--------------------+----------+
# | Max                | 2010     |
# +--------------------+----------+
# | Min                | 1901     |
# +--------------------+----------+

# %% [markdown]
# ### Race and Ethnicity

# %%
hua['Race Ethnicity'] = "0 Vacant HU No Race Ethnicity Data"
hua['Race Ethnicity'].notes = "Identify Race and Ethnicity Housing Unit Characteristics."

hua.loc[(hua['race'] == 1) & (hua['hispan'] == 0),'Race Ethnicity'] = "1 White alone, Not Hispanic"
hua.loc[(hua['race'] == 2) & (hua['hispan'] == 0),'Race Ethnicity'] = "2 Black alone, Not Hispanic"
hua.loc[(hua['race'].isin([3,4,5,6,7])) & (hua['hispan'] == 0),'Race Ethnicity'] = "3 Other Race, Not Hispanic"
hua.loc[(hua['hispan'] == 1),'Race Ethnicity'] = "4 Any Race, Hispanic"
hua.loc[(hua['gqtype'] >= 1),'Race Ethnicity'] = "5 Group Quarters no Race Ethnicity Data"

# %%
hua_re  = hua[["Race Ethnicity", "huestimate"]]
hua_re.dropna(inplace=True)

# %%
plt.rcParams["figure.figsize"]=12,12

# %%
hua.groupby(['Race Ethnicity']).sum().plot(kind='pie', y='huestimate')
# Out:
# <AxesSubplot:ylabel='huestimate'>

# %% [markdown]
# ### Population Spread in the Community

# %%
table = pd.pivot_table(hua, values='numprec', index=['Race Ethnicity'],
                                     margins = True, margins_name = 'Total',
                                     columns=['Tenure Status'], aggfunc=[np.sum]).rename(
    columns={'Total': 'Total Population', 'sum': ''})
table_title = "Table 1. Total Population by Race, Ethncity, and Tenure Status 2010."
varformat = {('','Total Population'): "{:,.0f}",
             ('','0 No Tenure Status'): "{:,.0f}",
             ('','1 Owner Occupied'): "{:,.0f}",
             ('','2 Renter Occupied'): "{:,.0f}"}
table.style.set_caption(table_title).format(varformat)
# Out:
# <style  type="text/css" >
# </style><table id="T_c2ff3_" ><caption>Table 1. Total Population by Race, Ethncity, and Tenure Status 2010.</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan="4"></th>    </tr>    <tr>        <th class="index_name level1" >Tenure Status</th>        <th class="col_heading level1 col0" >0 No Tenure Status</th>        <th class="col_heading level1 col1" >1 Owner Occupied</th>        <th class="col_heading level1 col2" >2 Renter Occupied</th>        <th class="col_heading level1 col3" >Total Population</th>    </tr>    <tr>        <th class="index_name level0" >Race Ethnicity</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c2ff3_level0_row0" class="row_heading level0 row0" >0 Vacant HU No Race Ethnicity Data</th>
#                         <td id="T_c2ff3_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_c2ff3_row0_col1" class="data row0 col1" >nan</td>
#                         <td id="T_c2ff3_row0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_c2ff3_row0_col3" class="data row0 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_c2ff3_level0_row1" class="row_heading level0 row1" >1 White alone, Not Hispanic</th>
#                         <td id="T_c2ff3_row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_c2ff3_row1_col1" class="data row1 col1" >2,631</td>
#                         <td id="T_c2ff3_row1_col2" class="data row1 col2" >2,900</td>
#                         <td id="T_c2ff3_row1_col3" class="data row1 col3" >5,531</td>
#             </tr>
#             <tr>
#                         <th id="T_c2ff3_level0_row2" class="row_heading level0 row2" >2 Black alone, Not Hispanic</th>
#                         <td id="T_c2ff3_row2_col0" class="data row2 col0" >nan</td>
#                         <td id="T_c2ff3_row2_col1" class="data row2 col1" >7</td>
#                         <td id="T_c2ff3_row2_col2" class="data row2 col2" >17</td>
#                         <td id="T_c2ff3_row2_col3" class="data row2 col3" >24</td>
#             </tr>
#             <tr>
#                         <th id="T_c2ff3_level0_row3" class="row_heading level0 row3" >3 Other Race, Not Hispanic</th>
#                         <td id="T_c2ff3_row3_col0" class="data row3 col0" >nan</td>
#                         <td id="T_c2ff3_row3_col1" class="data row3 col1" >136</td>
#                         <td id="T_c2ff3_row3_col2" class="data row3 col2" >191</td>
#                         <td id="T_c2ff3_row3_col3" class="data row3 col3" >327</td>
#             </tr>
#             <tr>
#                         <th id="T_c2ff3_level0_row4" class="row_heading level0 row4" >4 Any Race, Hispanic</th>
#                         <td id="T_c2ff3_row4_col0" class="data row4 col0" >nan</td>
#                         <td id="T_c2ff3_row4_col1" class="data row4 col1" >187</td>
#                         <td id="T_c2ff3_row4_col2" class="data row4 col2" >524</td>
#                         <td id="T_c2ff3_row4_col3" class="data row4 col3" >711</td>
#             </tr>
#             <tr>
#                         <th id="T_c2ff3_level0_row5" class="row_heading level0 row5" >5 Group Quarters no Race Ethnicity Data</th>
#                         <td id="T_c2ff3_row5_col0" class="data row5 col0" >47</td>
#                         <td id="T_c2ff3_row5_col1" class="data row5 col1" >nan</td>
#                         <td id="T_c2ff3_row5_col2" class="data row5 col2" >nan</td>
#                         <td id="T_c2ff3_row5_col3" class="data row5 col3" >47</td>
#             </tr>
#             <tr>
#                         <th id="T_c2ff3_level0_row6" class="row_heading level0 row6" >Total</th>
#                         <td id="T_c2ff3_row6_col0" class="data row6 col0" >47</td>
#                         <td id="T_c2ff3_row6_col1" class="data row6 col1" >2,961</td>
#                         <td id="T_c2ff3_row6_col2" class="data row6 col2" >3,632</td>
#                         <td id="T_c2ff3_row6_col3" class="data row6 col3" >6,640</td>
#             </tr>
#     </tbody></table>

# %%
pop_map = viz.plot_gdf_map(hua_gdf,column='Tenure Status')
plt.title("Tenure Status")
# Out:
# Text(0.5, 1.0, 'Tenure Status')

# %%
#Grouping population
hua_gdf["new_pop"] = hua_gdf.numprec.copy()
hua_gdf.new_pop[hua_gdf.numprec==0] = "No people"
hua_gdf.new_pop[(hua_gdf.numprec==1) | (hua_gdf.numprec==2)] = "1-2 people"
hua_gdf.new_pop[(hua_gdf.numprec>2) & (hua_gdf.numprec<6)] = "3-5 people"
hua_gdf.new_pop[hua_gdf.numprec>5] = "More than 5 people"

# %%
hua_gdf.new_pop.value_counts()
# Out:
# 1-2 people            2220
# No people             1683
# 3-5 people             749
# More than 5 people      89
# Name: new_pop, dtype: int64

# %%
data = [[len(hua_gdf.new_pop[hua_gdf.new_pop=="No people"]), len(hua_gdf.new_pop[hua_gdf.new_pop=="1-2 people"]), 
         len(hua_gdf.new_pop[hua_gdf.new_pop=="3-5 people"]), len(hua_gdf.new_pop[hua_gdf.new_pop=="More than 5 people"])]]
renter = pd.DataFrame(data, columns=["No people", "1-2 people", "3-5 people", "More than 5 people"], index=["#Buildings"])
renter
# Out:
#             No people  1-2 people  3-5 people  More than 5 people
# #Buildings       1683        2220         749                  89

# %%
hua["Buildings"] = 1
hua["new_pop"] = hua_gdf.new_pop.copy()

# %%
hua.groupby(['new_pop']).sum().plot(kind='pie', y='Buildings')
# Out:
# <AxesSubplot:ylabel='Buildings'>

# %%
pop_map = viz.plot_gdf_map(hua_gdf,column='new_pop')
plt.title("Number of people per household")
# Out:
# Text(0.5, 1.0, 'Number of people per household')

# %% [markdown]
# ### Vacany Variable Description
#
#
#
# | Vacancy | Description |
# | --- | --- |
# | 0 | NA Not vacant |
# | 1 |  For rent |
# | 2 |  Rented, not occupied |
# | 3 |  For sale only |
# | 4 |  Sold, not occupied |
# | 5 |  For Seasonal,recreastional or occasional use|
# | 6 |  For Migrant workers|
# | 7 |  Other vanant|

# %%
## Converting the numberical values to strings
hua_gdf["new_vacancy"] = hua_gdf.vacancy.copy()
hua_gdf.new_vacancy[hua_gdf.vacancy==0] = "NA Not vacant"
hua_gdf.new_vacancy[hua_gdf.vacancy==1] = "For rent"
hua_gdf.new_vacancy[hua_gdf.vacancy==2] = "Rented, not occupied"
hua_gdf.new_vacancy[hua_gdf.vacancy==3] = "For sale only"
hua_gdf.new_vacancy[hua_gdf.vacancy==4] = "Sold, not occupied"
hua_gdf.new_vacancy[hua_gdf.vacancy==5] = "For Seasonal,recreastional or occasional use"
hua_gdf.new_vacancy[hua_gdf.vacancy==6] = "For Migrant workers"
hua_gdf.new_vacancy[hua_gdf.vacancy==7] = "Other vanant"

# %%
vacancy = viz.plot_gdf_map(hua_gdf,column='new_vacancy')
plt.title("Vacancy")
# Out:
# Text(0.5, 1.0, 'Vacancy')
